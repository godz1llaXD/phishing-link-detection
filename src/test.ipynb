# %%
import sys 
import os 
sys.path.append(os.path.abspath(".."))
from src.predict import analyze_url

url = "https://chatgpt.com/c/69522c09-1ff8-8324-8f91-d608960f5780"

result = analyze_url(url)

print(result)
# Out:
# {'prediction': 1, 'probability': 1.0, 'reasons': ['High randomness in URL', 'High number of digits']}
